# %%
#import in-built libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
#Attach a csv file to extract data from it
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c0af12d4-5e67-48c5-9fce-575cd66ca322" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0af12d4-5e67-48c5-9fce-575cd66ca322">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Loading it into a variable
df = pd.read_csv("Salaries (3).csv")

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.sample()
# Out:
#     rank discipline  phd  service   sex  salary
# 10  Prof          B   39       33  Male  128250

# %%
df.head(13)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.dtypes(service)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ed93de3eb4b8> in <module>
# ----> 1 df.dtypes(service)
#
# NameError: name 'service' is not defined

# %%
df['service'].dtypes
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
df.size
# Out:
# 468

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (78, 6)

# %%
df.values
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %%
df.shape[0]
# Out:
# 78

# %%
df.shape[1]
# Out:
# 6

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df[['discipline', 'rank']].dtypes
# Out:
# discipline    object
# rank          object
# dtype: object

# %%
df.columns.max()
# Out:
# 'sex'

# %%
df.columns.min()
# Out:
# 'discipline'

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.mean()
# Out:
# <ipython-input-56-c61f0c8f89b5>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.dropna()
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.std()
# Out:
# <ipython-input-14-ce97bb7eaef8>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df.sample()
# Out:
#          rank discipline  phd  service   sex  salary
# 34  AssocProf          B   12        8  Male  119800

# %%
df.head().mean()
# Out:
# <ipython-input-16-a5a8f8e50aa9>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.head().mean()
# phd            30.2
# service        24.8
# salary     125296.0
# dtype: float64

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df['rank'].unique()
# Out:
# array(['Prof', 'AssocProf', 'AsstProf'], dtype=object)

# %%
df_rank = df.groupby(['rank'])

# %%
df_rank.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df_rank.std()
# Out:
#                  phd    service        salary
# rank
# AssocProf   5.589597   5.879124  18571.183714
# AsstProf    2.738079   1.750522   9381.245301
# Prof       10.185834  11.255766  24850.287853

# %%
df_rank.describe()
# Out:
#             phd                                                      service  \
#           count       mean        std   min    25%   50%   75%   max   count
# rank
# AssocProf  13.0  15.076923   5.589597   9.0  12.00  13.0  19.0  26.0    13.0
# AsstProf   19.0   5.052632   2.738079   1.0   3.50   4.0   7.0  11.0    19.0
# Prof       46.0  27.065217  10.185834  12.0  19.25  24.5  34.5  56.0    46.0
#
#                       ...              salary                               \
#                 mean  ...    75%   max  count           mean           std
# rank                  ...
# AssocProf  11.307692  ...  11.00  24.0   13.0   91786.230769  18571.183714
# AsstProf    2.210526  ...   3.00   6.0   19.0   81362.789474   9381.245301
# Prof       21.413043  ...  26.75  51.0   46.0  123624.804348  24850.287853
#
#
#                min       25%       50%        75%       max
# rank
# AssocProf  62884.0   74830.0  103613.0  104542.00  119800.0
# ...

# %%
df_rank.max()
# Out:
#           discipline  phd  service   sex  salary
# rank
# AssocProf          B   26       24  Male  119800
# AsstProf           B   11        6  Male   97032
# Prof               B   56       51  Male  186960

# %%
df_rank.min()
# Out:
#           discipline  phd  service     sex  salary
# rank
# AssocProf          A    9        6  Female   62884
# AsstProf           A    1        0  Female   63100
# Prof               A   12        0  Female   57800

# %%
df_sex = df.groupby(['sex'])

# %%
df['sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['sex'].value_counts()
# Out:
# Male      39
# Female    39
# Name: sex, dtype: int64

# %%
df_sex.describe()
# Out:
#          phd                                                    service  \
#        count       mean        std  min   25%   50%   75%   max   count
# sex
# Female  39.0  16.512821   9.784176  2.0  10.0  17.0  23.5  39.0    39.0
# Male    39.0  22.897436  14.138032  1.0  12.0  21.0  31.5  56.0    39.0
#
#                    ...             salary                               \
#              mean  ...   75%   max  count           mean           std
# sex                ...
# Female  11.564103  ...  17.5  36.0   39.0  101002.410256  25952.127317
# Male    18.538462  ...  25.0  51.0   39.0  115045.153846  29110.516397
#
#
#             min      25%       50%       75%       max
# sex
# Female  62884.0  77250.0  103750.0  117002.5  161101.0
# Male    57800.0  92000.0  107300.0  132991.5  186960.0
#
# [2 rows x 24 columns]

# %%
df_sex.max()
# Out:
#         rank discipline  phd  service  salary
# sex
# Female  Prof          B   39       36  161101
# Male    Prof          B   56       51  186960

# %%
df_sex.min()
# Out:
#              rank discipline  phd  service  salary
# sex
# Female  AssocProf          A    2        0   62884
# Male    AssocProf          A    1        0   57800

# %%
df_sex.std()
# Out:
#               phd    service        salary
# sex
# Female   9.784176   8.813252  25952.127317
# Male    14.138032  13.999711  29110.516397

# %%
df_sex.sample()
# Out:
#          rank discipline  phd  service     sex  salary
# 71  AssocProf          B   12        9  Female   71065
# 5        Prof          A   20       20    Male  122400

# %%
df.groupby(['rank', 'discipline', 'sex'])[['salary', 'phd']].mean()
# Out:
#                                     salary        phd
# rank      discipline sex
# AssocProf A          Female   72128.500000  18.500000
#                      Male     81285.000000  20.000000
#           B          Female   99435.666667  13.500000
#                      Male    113404.000000  10.500000
# AsstProf  A          Female   72933.333333   4.833333
#                      Male     79000.000000   3.000000
#           B          Female   84189.800000   6.600000
#                      Male     88224.000000   4.666667
# Prof      A          Female  109631.875000  26.500000
#                      Male    113164.400000  28.933333
#           B          Female  131836.200000  21.500000
#                      Male    137989.076923  29.538462

# %%
df.groupby(['sex', 'rank'])['salary'].mean()
# Out:
# sex     rank
# Female  AssocProf     88512.800000
#         AsstProf      78049.909091
#         Prof         121967.611111
# Male    AssocProf    102697.666667
#         AsstProf      85918.000000
#         Prof         124690.142857
# Name: salary, dtype: float64

# %%
df.groupby(['sex', 'rank', 'discipline'])['salary'].min()
# Out:
# sex     rank       discipline
# Female  AssocProf  A              62884
#                    B              71065
#         AsstProf   A              63100
#                    B              74692
#         Prof       A              90450
#                    B             105450
# Male    AssocProf  A              81285
#                    B             107008
#         AsstProf   A              73000
#                    B              75044
#         Prof       A              57800
#                    B              99418
# Name: salary, dtype: int64

# %%
df['salary'].max()
# Out:
# 186960

# %%
sns.displot(data=df, x='rank', col='sex')

# %%
# DataFrame Sorting
# False sort arranges in Descending order of salaries
df.groupby('rank',sort=False)['salary'].max()
# Out:
# rank
# Prof         186960
# AssocProf    119800
# AsstProf      97032
# Name: salary, dtype: int64

# %%
# True sort arranges in Ascending order of salaries
df.groupby('rank',sort=True)['salary'].max()
# Out:
# rank
# AssocProf    119800
# AsstProf      97032
# Prof         186960
# Name: salary, dtype: int64

# %%
# DataFrame Filtering after grouping
df.groupby((df['sex']=='Female')&(df['rank']=='Prof'))['salary'].min()
# Out:
# False    57800
# True     90450
# Name: salary, dtype: int64

# %%
df.groupby((df['sex']=='Female')&(df['rank']=='Prof'))['salary'].mean()
# Out:
# False    103840.633333
# True     121967.611111
# Name: salary, dtype: float64

# %%
# Data Filtering
df[(df['sex']=='Female')&(df['rank']=='Prof')]['salary'].min()
# Out:
# 90450

# %%
print('The minimum salary of Assosciate Professor is: Rs.',df[df['rank']=='AsstProf']['salary'].min())
# Out:
# The minimum salary of Assosciate Professor is: Rs. 63100

# %%
print('The maximun salary of Assosciate Professor is: Rs.',df[df['rank']=='AsstProf']['salary'].max())
# Out:
# The maximun salary of Assosciate Professor is: Rs. 97032

# %%
df[(df['rank']=='AsstProf') & (df['discipline']=='A')]
# Out:
#         rank discipline  phd  service     sex  salary
# 22  AsstProf          A    4        2    Male   73000
# 23  AsstProf          A    2        0    Male   85000
# 53  AsstProf          A    5        3  Female   73500
# 55  AsstProf          A    2        0  Female   72500
# 57  AsstProf          A    3        1  Female   72500
# 66  AsstProf          A    7        6  Female   63100
# 68  AsstProf          A    4        2  Female   77500
# 70  AsstProf          A    8        3  Female   78500

# %%
df[(df['rank']=='Prof') & (df['discipline']=='B')]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 4   Prof          B   20       18    Male  104800
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 25  Prof          B   35       31    Male   99418
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 33  Prof          B   18       18    Male  120000
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 44  Prof          B   23       19  Female  151768
# 45  Prof          B   25       25  Female  140096
# 48  Prof          B   17       17  Female  111512
# 49  Prof          B   17       18  Female  122960
# ...

# %%
print('The avg phd & salary of Male AsstProf is:\n',df[(df['rank']=='AsstProf') & (df['sex']=='Male')][['phd', 'salary']].mean())
# Out:
# The avg phd & salary of Male AsstProf is:
#  phd           4.25
# salary    85918.00
# dtype: float64

# %%
print('The avg salary of Female AsstProf is: Rs.',df[(df['rank']=='AsstProf') & (df['sex']=='Female')]['salary'].mean())
# Out:
# The avg salary of Female AsstProf is: Rs. 78049.90909090909

# %%
df[(df['sex']=='Female') & (df['rank']=='Prof')][df['salary'] > 120000].mean()
# Out:
# <ipython-input-87-05c1fb1a0ff4>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[(df['sex']=='Female') & (df['rank']=='Prof')][df['salary'] > 120000].mean()
# <ipython-input-87-05c1fb1a0ff4>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[(df['sex']=='Female') & (df['rank']=='Prof')][df['salary'] > 120000].mean()
# phd            24.333333
# service        20.888889
# salary     137600.000000
# dtype: float64

# %%
print('Minimum yrs of service for Prof is: ',df[df['rank']=='Prof']['service'].min(),'yrs')
# Out:
# Minimum yrs of service for Prof is:  0 yrs

# %%
df.iloc[[0]]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960

# %%
df.iloc[[4]]
# Out:
#    rank discipline  phd  service   sex  salary
# 4  Prof          B   20       18  Male  104800

# %%
df.iloc[[-1]]
# Out:
#     rank discipline  phd  service     sex  salary
# 77  Prof          A   23       15  Female  109646

# %%
df.iloc[:, 0]
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df.iloc[:, -1]
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df.iloc[2,4]

# %%
df.iloc[0:7]
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285

# %%
df.iloc[:, 0:2]
# Out:
#          rank discipline
# 0        Prof          B
# 1        Prof          A
# 2        Prof          A
# 3        Prof          A
# 4        Prof          B
# ..        ...        ...
# 73       Prof          B
# 74  AssocProf          B
# 75       Prof          B
# 76       Prof          A
# 77       Prof          A
#
# [78 rows x 2 columns]

# %%
df.iloc[1:3, 0:2]
# Out:
#    rank discipline
# 1  Prof          A
# 2  Prof          A

# %%
df.iloc[[0,3], [2,3]]
# Out:
#    phd  service
# 0   56       49
# 3   40       31

# %%
df.iloc[0:7]
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285

# %%
df.iloc[-3:]
# Out:
#     rank discipline  phd  service     sex  salary
# 75  Prof          B   17       17  Female  124312
# 76  Prof          A   28       14  Female  109954
# 77  Prof          A   23       15  Female  109646

# %%
df.iloc[2:8]
# Out:
#         rank discipline  phd  service   sex  salary
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300

# %%
df.iloc[:, -1]
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
df.iloc[[3]]
# Out:
#    rank discipline  phd  service   sex  salary
# 3  Prof          A   40       31  Male  131205

# %%
df.iloc[[0,5], 5]
# Out:
# 0    186960
# 5    122400
# Name: salary, dtype: int64

# %%
df.iloc[:, [0,3]]
# Out:
#          rank  service
# 0        Prof       49
# 1        Prof        6
# 2        Prof       20
# 3        Prof       31
# 4        Prof       18
# ..        ...      ...
# 73       Prof       10
# 74  AssocProf        6
# 75       Prof       17
# 76       Prof       14
# 77       Prof       15
#
# [78 rows x 2 columns]

# %%
df.iloc[[4,2]]
# Out:
#    rank discipline  phd  service   sex  salary
# 4  Prof          B   20       18  Male  104800
# 2  Prof          A   23       20  Male  110515

# %%
df.iloc[-2:]
# Out:
#     rank discipline  phd  service     sex  salary
# 76  Prof          A   28       14  Female  109954
# 77  Prof          A   23       15  Female  109646

# %%
df.iloc[-3:,-2:]
# Out:
#        sex  salary
# 75  Female  124312
# 76  Female  109954
# 77  Female  109646

# %%
df.iloc[2:9]
# Out:
#         rank discipline  phd  service   sex  salary
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350

# %%
df[['phd','salary']].agg(['min','mean','max'])
# Out:
#             phd         salary
# min    1.000000   57800.000000
# mean  19.705128  108023.782051
# max   56.000000  186960.000000

# %%
df['salary'].agg(['mean','std'])
# Out:
# mean    108023.782051
# std      28293.661022
# Name: salary, dtype: float64

# %%
df[(df['sex']=='Male') & (df['rank']=='Prof')]['salary'].agg(['mean','max'])
# Out:
# mean    124690.142857
# max     186960.000000
# Name: salary, dtype: float64

# %%
df[(df['sex']=='Female') & (df['rank']=='AsstProf')][['salary','phd']].agg(['min','mean','max','std'])
# Out:
#             salary        phd
# min   63100.000000   2.000000
# mean  78049.909091   5.636364
# max   97032.000000  11.000000
# std    9371.996121   2.975659
